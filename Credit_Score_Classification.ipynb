# %% [markdown]
# <a href="https://colab.research.google.com/github/Keshav1516/credit_card_score_predictor/blob/main/Credit_Score_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Important Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing the dataset
data= pd.read_csv("/content/train.csv")

#loading the sample dataset
data.sample()
# Out:
#         ID  Customer_ID  Month     Name   Age         SSN Occupation  \
# 2389  9215        25479      6  Araxiab  26.0  63088008.0    Manager
#
#       Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 2389       62316.63              4895.0525                8.0  ...
#
#       Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 2389    Standard            417.27                 35.129144
#
#      Credit_History_Age  Payment_of_Min_Amount  Total_EMI_per_month  \
# 2389              320.0                     NM            82.733177
#
#       Amount_invested_monthly                 Payment_Behaviour  \
# 2389                64.106518  High_spent_Medium_value_payments
#
#      Monthly_Balance  Credit_Score
# 2389        495.5625      Standard
#
# [1 rows x 28 columns]

# %%
# Let's view the dataset summary
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  int64
#  1   Customer_ID               100000 non-null  int64
#  2   Month                     100000 non-null  int64
#  3   Name                      100000 non-null  object
#  4   Age                       100000 non-null  float64
#  5   SSN                       100000 non-null  float64
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  float64
#  8   Monthly_Inhand_Salary     100000 non-null  float64
#  9   Num_Bank_Accounts         100000 non-null  float64
#  10  Num_Credit_Card           100000 non-null  float64
#  11  Interest_Rate             100000 non-null  float64
#  12  Num_of_Loan               100000 non-null  float64
# ...

# %%
# Let's check the deminsion of the dataset
print(data.shape)
# Out:
# (100000, 28)

# %%
# Check the columns names
print(data.columns)
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
# Making all column names in format.
data.columns= data.columns.str.strip().str.lower().str.replace(" ","_")

# %%
# Check the there is any null values in the dataset.
print(data.isnull().sum())
# Out:
# id                          0
# customer_id                 0
# month                       0
# name                        0
# age                         0
# ssn                         0
# occupation                  0
# annual_income               0
# monthly_inhand_salary       0
# num_bank_accounts           0
# num_credit_card             0
# interest_rate               0
# num_of_loan                 0
# type_of_loan                0
# delay_from_due_date         0
# num_of_delayed_payment      0
# changed_credit_limit        0
# num_credit_inquiries        0
# credit_mix                  0
# outstanding_debt            0
# credit_utilization_ratio    0
# credit_history_age          0
# payment_of_min_amount       0
# total_emi_per_month         0
# amount_invested_monthly     0
# payment_behaviour           0
# monthly_balance             0
# credit_score                0
# dtype: int64

# %%
# Let’s have a look at the Credit_Score column values.
data["credit_score"].value_counts()
# Out:
# credit_score
# Standard    53174
# Poor        28998
# Good        17828
# Name: count, dtype: int64

# %%
X = ["Good", "Standard", "Poor"]

# %%
sns.boxplot(data, y="occupation", x="credit_score", palette=('Green','yellow','red'))
plt.title("Credit Score based on Occupation", )
plt.legend(labels= X ,loc="upper right")
plt.show()

# %%
sns.boxplot(data, y="annual_income", x="credit_score", palette=('Green','yellow','red'))
plt.title("Credit Score based on Annual Income", )
plt.legend(labels= X ,loc="upper right")
plt.show()

# %%
sns.boxplot(data, y="monthly_inhand_salary", x="credit_score", palette=('Green','yellow','red'))
plt.title("Credit Score based on Monthly Inhand Salary", )
plt.legend(labels= X ,loc="upper right")
plt.show()

# %%
sns.boxplot(data, y="num_credit_card", x="credit_score", palette=('Green','yellow','red'))
plt.title("Credit Score based on Number of Credit Card ", )
plt.legend(labels= X ,loc="upper right")
plt.show()

# %%
sns.boxplot(data, y="num_bank_accounts", x="credit_score", palette=('Green','yellow','red'))
plt.title("Credit Score based on Number of Bank Accounts ", )
plt.legend(labels= X ,loc="upper right")
plt.show()

# %%
sns.boxplot(data, y="interest_rate", x="credit_score", palette=('Green','yellow','red'))
plt.title("Credit Score based on Number of Interest Rate", )
plt.legend(labels= X ,loc="upper right")
plt.show()

# %%
sns.boxplot(data, y="num_of_loan", x="credit_score", palette=('Green','yellow','red'))
plt.title("Credit Score based on Number of Loans Taken by the Person", )
plt.legend(labels= X ,loc="upper right")
plt.show()

# %%
sns.boxplot(data, y="delay_from_due_date", x="credit_score", palette=('Green','yellow','red'))
plt.title("Credit Score based on Number of Days Delayed for the Credit Card Payments", )
plt.legend(labels= X ,loc="upper right")
plt.show()

# %%
sns.boxplot(data, y="num_of_delayed_payment", x="credit_score", palette=('Green','yellow','red'))
plt.title("Credit Score based on Number of Delayed Payments", )
plt.legend(labels= X ,loc="upper right")
plt.show()

# %%
sns.boxplot(data, y="outstanding_debt", x="credit_score", palette=('Green','yellow','red'))
plt.title("Credit Score based on Outstanding Debits", )
plt.legend(labels= X ,loc="upper right")
plt.show()

# %%
sns.boxplot(data, y="credit_utilization_ratio", x="credit_score", palette=('Green','yellow','red'))
plt.title("Credit Score based on Credit Utilization Ratio", )
plt.legend(labels= X ,loc="upper right")
plt.show()

# %%
sns.boxplot(data, y="credit_history_age", x="credit_score", palette=('Green','yellow','red'))
plt.title("Credit Score based on Credit History Age", )
plt.legend(labels= X ,loc="upper right")
plt.show()

# %%
sns.boxplot(data, y="total_emi_per_month", x="credit_score", palette=('Green','yellow','red'))
plt.title("Credit Score based on Total EMI Per Month" )
plt.legend(labels= X ,loc="upper right")
plt.show()

# %%
sns.boxplot(data, y="amount_invested_monthly", x="credit_score", palette=('Green','yellow','red'))
plt.title("Credit Score based on Amount Invested Monthly" )
plt.legend(labels= X ,loc="upper right")
plt.show()

# %%
sns.boxplot(data, y="monthly_balance", x="credit_score", palette=('Green','yellow','red'))
plt.title("Credit Score based on Monthly Based Left" )
plt.legend(labels= X ,loc="upper right")
plt.show()

# %%
# Mapping the target columns for preparing the model.
data["credit_mix"]= data["credit_mix"].map({"Standard":1, "Good":2, "Bad":0})

# %%
data.head()
# Out:
#      id  customer_id  month           name   age          ssn occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4  Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    annual_income  monthly_inhand_salary  num_bank_accounts  ...  credit_mix  \
# 0       19114.12            1824.843333                3.0  ...           2
# 1       19114.12            1824.843333                3.0  ...           2
# 2       19114.12            1824.843333                3.0  ...           2
# 3       19114.12            1824.843333                3.0  ...           2
# 4       19114.12            1824.843333                3.0  ...           2
#
#    outstanding_debt  credit_utilization_ratio credit_history_age  \
# ...

# %%
from sklearn.model_selection import train_test_split

x= np.array(data[["annual_income", "monthly_inhand_salary",
                   "num_bank_accounts", "num_credit_card",
                   "interest_rate", "num_of_loan",
                   "delay_from_due_date", "num_of_delayed_payment",
                   "credit_mix", "outstanding_debt",
                   "credit_history_age", "monthly_balance"]])
y= np.array(data[["credit_score"]])

# %%
xtrain, xtest, ytrain, ytest= train_test_split(x, y, test_size=0.33, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
model= RandomForestClassifier()
model.fit(xtrain, ytrain)
# Out:
# RandomForestClassifier()

# %%
print("Credit Score Prediction:")
a = float(input("Annual Income :"))
b = float(input("Monthly Inhand Salary :"))
c = float(input("Number Bank Accounts :"))
d = float(input("Number Credit Card :"))
e = float(input("Interest Rate :"))
f = float(input("Number of Loan"))
g = float(input("Average number of days delayed by the person :"))
h = float(input("Number of delayed payments :"))
i = float(input("Credit Mix (Bad: 0, Standard: 1, Good: 3) :"))
j = float(input("Outstanding Debt :"))
k = float(input("Credit History Age :"))
l = float(input("Monthly Balance :"))

features = np.array([[a,b,c,d,e,f,g,h,i,j,k,l]])
print("Predict Credit Score =", model.predict(features))
# Out:
# Credit Score Prediction:
# Annual Income :19114.12
# Monthly Inhand Salary :1824.8989
# Number Bank Accounts :3
# Number Credit Card :2
# Interest Rate :10
# Number of Loan2
# Average number of days delayed by the person :12
# Number of delayed payments :3
# Credit Mix (Bad: 0, Standard: 1, Good: 3) :3
# Outstanding Debt :250
# Credit History Age :200
# Monthly Balance :310
# Predict Credit Score = ['Good']
